# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "g+" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "g+--" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "g+-." )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "g+-" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "g+:" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , ":r+" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "gh:" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "gH:" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , "gD:" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="cyan" , marker="D" , linestyle=":" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="#666666" , marker="D" , linestyle=":" , markersize=8 )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="#666666" , marker="D" , linestyle=":" , markersize=4 , alpha=0.64 )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="#666666" , marker="D" , linestyle=":" , markersize=8 , alpha=0.1 )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="#666666" , marker="D" , linestyle=":" , markersize=8 , alpha=0.9 )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot ( x , y , color="brown" , marker="D" , linestyle=":" , markersize=8 , alpha=0.96 )
