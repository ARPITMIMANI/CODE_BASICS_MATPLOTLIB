# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist(blood_sugar)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=10 )
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=5 )
# Out:
# (array([6., 1., 2., 2., 2.]),
#  array([ 77. ,  91.6, 106.2, 120.8, 135.4, 150. ]),
#  <BarContainer object of 5 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=3 )
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=10 , rwidth=0.92 )
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=3 , rwidth=0.92 )
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=3 , rwidth=0.96 )
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[80,100,125,200] , rwidth=0.96 )
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 200.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[80,100,125,200] , rwidth=0.96 , color="green" )
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 200.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 , color="green" )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 , color="green" , histtype="step" )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x1feff627640>])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 , color="green" , histtype="bar" )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 , color="green" , histtype="stepfilled" )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x1feff73d930>])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist ( blood_sugar , bins=[75,100,125,150] , rwidth=0.96 , color="green" , histtype="barstacked" )
# Out:
# (array([7., 2., 4.]),
#  array([ 75., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist ( [blood_sugar_men,blood_sugar_women] , bins=[75,100,125,150] , 
          rwidth=0.96 , color=["green","orange"] , histtype="bar" )
# Out:
# (array([[7., 2., 4.],
#         [5., 4., 2.]]),
#  array([ 75., 100., 125., 150.]),
#  <a list of 2 BarContainer objects>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist ( [blood_sugar_men,blood_sugar_women] , bins=[75,100,125,150] , 
          rwidth=0.96 , color=["green","orange"] , histtype="bar" , label=["Men","Women"] )

plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("SUGAR RANGE")
plt.ylabel("NUMBER OF PATIENTS")
plt.title("BLOOD SUGAR ANALYSIS")

plt.hist ( [blood_sugar_men,blood_sugar_women] , bins=[75,100,125,150] , 
          rwidth=0.96 , color=["green","orange"] , histtype="bar" , label=["Men","Women"] )

plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("SUGAR RANGE")
plt.ylabel("NUMBER OF PATIENTS")
plt.title("BLOOD SUGAR ANALYSIS")

plt.hist ( [blood_sugar_men,blood_sugar_women] , bins=[75,100,125,150] , rwidth=0.96 , 
          color=["green","orange"] , histtype="bar" , label=["Men","Women"] , orientation="horizontal" )

plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("SUGAR RANGE")
plt.ylabel("NUMBER OF PATIENTS")
plt.title("BLOOD SUGAR ANALYSIS")

plt.hist ( [blood_sugar_men,blood_sugar_women] , bins=[75,100,125,150] , rwidth=0.96 , 
          color=["green","orange"] , histtype="bar" , label=["Men","Women"] , orientation="vertical" )

plt.legend()
