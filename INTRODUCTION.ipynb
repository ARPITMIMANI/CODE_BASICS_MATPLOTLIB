# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot ( x , y , color="orange" , linewidth=3 )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot ( x , y , color="orange" , linewidth=3 , linestyle="dotted" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot ( x , y , color="orange" , linewidth=3 , linestyle="dashed" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot ( x , y , color="orange" , linewidth=3 , linestyle="solid" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]
plt.plot ( x , y , color="orange" , linewidth=3 , linestyle="dashdot" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel("Day")
plt.ylabel("Temperature")

plt.title("Weather")
plt.plot ( x , y , color="orange" , linewidth=3 , linestyle="solid" )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.xlabel("Day")
plt.ylabel("Temperature")

plt.title("Weather")
plt.plot ( x , y , color="orange" , linewidth=1.6 , linestyle="solid" )
